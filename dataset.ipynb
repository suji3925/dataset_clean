# %% [markdown]
# <a href="https://colab.research.google.com/github/suji3925/dataset_clean/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-1a8a65a8-dfba-4b67-a655-c26492f1a7d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a8a65a8-dfba-4b67-a655-c26492f1a7d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"Phishing.xlsx")

# %%
data
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 1         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int64
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           9999 non-null   float64
#  4   UrlLength                           9999 non-null   float64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         9999 non-null   float64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          9999 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  id       NumDots  SubdomainLevel    PathLevel    UrlLength  \
# count  10000.000000  10000.000000    10000.000000  9999.000000  9999.000000
# mean    5000.500100      2.445100        0.586800     3.300230    70.272227
# std     2886.895507      1.346836        0.751214     1.863214    33.379559
# min        2.000000      1.000000        0.000000     0.000000    12.000000
# 25%     2500.750000      2.000000        0.000000     2.000000    48.000000
# 50%     5000.500000      2.000000        1.000000     3.000000    62.000000
# 75%     7500.250000      3.000000        1.000000     4.000000    84.000000
# max    10000.000000     21.000000       14.000000    18.000000   253.000000
#
#             NumDash  NumDashInHostname      AtSymbol  TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  9999.000000
# mean       1.818000           0.138900      0.000300     0.013101
# std        3.106258           0.545744      0.017319     0.113714
# ...

# %%
df.isnull()
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0     False    False           False      False      False    False
# 1     False    False           False      False      False    False
# 2     False    False           False       True      False    False
# 3     False    False           False      False      False    False
# 4     False    False           False      False      False    False
# ...     ...      ...             ...        ...        ...      ...
# 9995  False    False           False      False      False    False
# 9996  False    False           False      False      False    False
# 9997  False    False           False      False      False    False
# 9998  False    False           False      False      False    False
# 9999  False    False           False      False      False    False
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                 False     False        False          False  ...
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# NumDots                               0
# SubdomainLevel                        0
# PathLevel                             1
# UrlLength                             1
# NumDash                               0
# NumDashInHostname                     0
# AtSymbol                              0
# TildeSymbol                           1
# NumUnderscore                         0
# NumPercent                            1
# NumQueryComponents                    2
# NumAmpersand                          0
# NumHash                               1
# NumNumericChars                       0
# NoHttps                               0
# RandomString                          0
# IpAddress                             0
# DomainInSubdomains                    0
# DomainInPaths                         0
# HttpsInHostname                       0
# HostnameLength                        0
# PathLength                            0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates()
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# 5         6        3               1        1.0       42.0        1
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 1         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# 5         6        3               1        1.0       42.0        1
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df.dropna()
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 4         5        3               0        4.0       46.0        0
# 6         7        2               0        5.0       60.0        0
# 8         9        8               7        2.0       76.0        1
# 9        10        2               0        2.0       46.0        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df.drop(7)
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# 5         6        3               1        1.0       42.0        1
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# 5         6        3               1        1.0       42.0        1
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
avg=df['PathLevel'].mean()

# %%
df
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         2        3               1        3.0      144.0        0
# 2         3        3               1        NaN       58.0        0
# 3         4        3               1        6.0       79.0        1
# 4         5        3               0        4.0       46.0        0
# 5         6        3               1        1.0       42.0        1
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1        1.0       50.0        0
# 9996   9997        2               1        4.0       59.0        1
# 9997   9998        2               1        4.0       57.0        0
# 9998   9999        3               1        1.0       49.0        0
# 9999  10000        3               1        2.0       52.0        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                     0         0          0.0              2  ...
# ...

# %%
df.to_csv("new1.csv")

# %%
files.download("new1.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['PathLength'],color="green",bins=4)
plt.xticks(rotation=50)
plt.show()

# %%
plt.scatter(df['SubdomainLevel'],df['PathLength'],color="pink")
plt.title("SubdomainLevel vs PathLength")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(df['SubdomainLevel'],df['PathLength'],color="blue")
plt.title("SubdomainLevel vs PathLength")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(df['SubdomainLevel'],df['PathLength'],color="red")
plt.title("SubdomainLevel vs PathLength")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
plt.plot(df['SubdomainLevel'],df['PathLength'],color="red")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45,ha="right")
plt.subplot(2,3,2)

plt.bar(df['SubdomainLevel'],df['PathLength'],color="blue")
plt.title("SubdomainLevel vs PathLength")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45,ha="right")
plt.subplot(2,3,4)
plt.scatter(df['SubdomainLevel'],df['PathLength'],color="pink")
plt.title("SubdomainLevel vs PathLength")
plt.xlabel("SubdomainLevel")
plt.ylabel("PathLength")
plt.xticks(rotation=45,ha="right")
plt.subplot(2,3,5)
plt.hist(df['CLASS_LABEL'],color="green",bins=10)
plt.title("SubdomainLevel vs PathLength")
plt.xticks(rotation=100)
plt.xlabel("SubdomainLevel")
plt.tight_layout()
plt.savefig("report.png")
plt.show()
